# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

# %%
import pickle
from scatteringTables import *
d=pickle.load(open('iwcCoeff.pkl','rb'))
iwcCoeff=d['iwcCoeff']
peak=d['peak']
iwcCoeff_SSRG=np.polyfit(zST[2,:],np.log10(iwcST[2,:]),1)

# %%
# these coefficients are used to parameterize the variation of Nw as a function of height
# they are not used in this simplified example
dnCoeff=np.array([0.01975583*2.5, 0.22])
dn1D=np.polyval(dnCoeff,range(50))

# %%
# this section reads environmental data and defines a wrapper function for the lidar simulator
# the following reads the gaseous extinction (at the radiometer's frequencies) from the file kext_atm_allChannels.nc
with nc.Dataset('kext_atm_allChannels.nc','r') as f:
    kext_atm=f.variables['kext_atm'][:]
    kext_atm=np.array(kext_atm)

# this reads the profiles of temperature, pressure, water vapor and liquid water content from the file profiles.nc
with nc.Dataset('profiles.nc','r') as f:
    qv=f.variables['qv'][:]
    press=f.variables['press'][:]
    temp=f.variables['temp'][:]
    tempm=f.variables['tempm'][:]
    pressf=f.variables['pressf'][:]
    rho=f.variables['rho'][:]

kextCoeffL=[np.polyfit(zST[k,:200],np.log10(kextST[k,:200]),1) for k in range(4)]

npart=4
undef=0.0
nrefl=2
ice_type=1

# before running the following, build the lidar simulator
# cd  src_fort
# gfortran -c -fPIC band_dble.f90 
# cd ..
# f2py -c -m lidarSim src_fort/lidar_simulator.F90 src_fort/bisection.f90 src_fort/radtran_tau_dble.f src_fort/rosen.f src_fort/band_dble.o 
import lidarSim as lidar
def get_pnorm(nz,dr,temp1,pres1,presf1,qv1,iwc1,rho1,dm_ice):
    h1=dr/2+np.arange(nz)*dr
    h1f=np.arange(nz)*dr
    q_lsice1=iwc1/rho1*1e-3
    q_lsice=q_lsice1[np.newaxis,:]
    pres1=pres1[np.newaxis,:]
    presf1=presf1[np.newaxis,:]
    temp1=temp1[np.newaxis,:]
    q_lsliq=np.zeros((1,nz),float)
    ls_radice=dm_ice/2*1e-3
    ls_radice=ls_radice[np.newaxis,:]
    ls_radliq=np.zeros((1,nz),float)
    q_cvice=np.zeros((1,nz),float)
    cv_radice=np.zeros((1,nz),float)
    q_cvliq=np.zeros((1,nz),float)
    cv_radliq=np.zeros((1,nz),float)
    temp=temp1
    pres=pres1
    presf=presf1
    pmol,pnorm,pnorm_perp_tot,\
        tautot,betatot_liq,\
        betatot_ice,\
        betatot,refl, \
        zheight,\
        beta_mol, tau_mol,\
        alpha= lidar.lidar_simulator(npart,nrefl,undef,\
                                     pres1,presf1,\
                                     temp1,
                                     q_lsliq,q_lsice,\
                                     q_cvliq,\
                                     q_cvice,\
                                     ls_radliq,\
                                     ls_radice,\
                                     cv_radliq,cv_radice,\
                                     ice_type)
    return pmol,pnorm

# %%
# this module reads the cloudsat data and selects profiles meeting the criteria described in Grecu and Yorks (2023)
from csIO import *
import numpy as np
import matplotlib.pyplot as plt

def process(dbz,cpr_cmask,temp,iwc,re,height,iwp):
    a=np.nonzero(np.array(iwp)>0)
    b=np.nonzero(temp[a].max(axis=1)>280)
    a=a[0][b]
    temp0L=[]
    isfcPrecip=0
    iwp1L=[]
    iwp2L=[]
    iwcL=[]
    reL=[]
    zwL=[]
    iL=[]
    dbzL=[]
    ikL=[]
    hL=[]
    for i in a[0:]:
        b1=np.nonzero(temp[i]<273.15)
        ik=b1[0][-1]
        nprecip1=np.nonzero(cpr_cmask[i,ik:100]>30)
        temp0L.append(ik)
        if(len(nprecip1[0])>3):
            isfcPrecip+=1
            dbz[i,:]=-99
        else:
            if ik+3-40>0:
                iwp1L.append(iwp[i])
                iwp2L.append(iwc[i,ik+3-50:ik+3].data.sum()*0.24)
                iwcL.append(iwc[i,:])
                reL.append(re[i,:])
                zwL.append(dbz[i,ik+3-50:ik+3])
                iL.append(i)
                dbzL.append(dbz[i,:])
                ikL.append(ik)
                hL.append(height[i,ik+3])
    return iwp1L,iwp2L,zwL,iwcL,reL,iL,dbzL,ikL,hL

fs=sorted(glob.glob("sampleData/2019*2C*hdf"))
fs_2B=sorted(glob.glob("sampleData/2019*2B*hdf"))
import xarray as xr
for i,f in enumerate(fs[:1]):
    iwc,dbz_sim,temp2C,re,height,lonC,latC,iwp=read2C_ICE(f)
    fh=Dataset(fs_2B[i])
    dbz=fh['Radar_Reflectivity'][:]/100.
    cpr_cmask=fh['CPR_Cloud_mask'][:]
    iwp1L,iwp2L,zwL,iwcL,reL,iL,dbzL,ikL,hL_2C=process(dbz,cpr_cmask,temp2C,iwc,re,height,iwp)
    break
print(f,fs_2B[i])
# Out:
# sampleData/2019151234028_69732_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf sampleData/2019151234028_69732_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf

# %%
import glob
#glob.glob("CloudSat_2B/*nc")
fCS_2B=sorted(glob.glob("CloudSat_2B/*hdf"))
f2ICE=sorted(glob.glob("data/*2C*hdf"))
fCS_2B=fCS_2B[14:]
print(len(fCS_2B),len(f2ICE))
print(fCS_2B[0],f2ICE[0])
# Out:
# 132 230
# CloudSat_2B/2019151234028_69732_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019151234028_69732_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf

# %%
from scipy.ndimage import gaussian_filter1d
import lidarSim as lidSim
def simObs(dbzL,iwcL,ikL,qv,temp,press,pressf):
    zKuL=[]
    tbL=[]
    epsL=[]
    dm_SSRGL=[]
    pnormL=[]
    pmolL=[]
    fisot=2.7
    umu=np.cos(np.deg2rad(53.0))
    nt1,nz=qv.shape
    height=np.arange(nz+1)*0.240
    nt=len(dbzL)
    dbzL=np.array(dbzL)
    iwcL=np.array(iwcL)
    iwc_SSRG=np.zeros((nt,50),float)
    dm_SSRG=np.zeros((nt,50),float)
    zKu=np.zeros((nt,50),float)-99.9
    dnL=[]
    ifreqC=[0,1,2,3,3,3,3,3,3,4,4,4]
    print(nt)
    for i in range(0,nt):
        i1=i
        zw1=dbzL[i1,ikL[i1]-60+3:ikL[i1]+3][::-1]
        iwc1D=iwcL[i1,ikL[i1]-60+3:ikL[i1]+3][::-1]
        a1=np.nonzero(iwc1D>0)
        kextI=np.zeros((50,12),float)
        salbI=np.zeros((50,12),float)
        asymI=np.zeros((50,12),float)
        ic=np.random.randint(0,30)
        kext1D=kext_atm[ic,:,:].copy()
        salb1D=np.zeros((64,12),float)
        asym1D=np.zeros((64,12),float)
        dnp=np.random.randn(64)
        dnp=gaussian_filter1d(dnp,2)
        dn1Dp=dnp+1.97+np.arange(-14,50)*0.24*0.161
        iwcsum=iwc1D.sum()
        #print(i,iwcsum)
        for k in a1[0]:
            if k>49:
                continue
            zw11=zw1[k]
            if(zw1[k]-10*(dn1Dp[k])>=zST[2,0]):
                ifind = lidSim.bisection2(zST[2,:],zw1[k]-10*(dn1Dp[k]))
                if ifind>599:
                    ifind=599
                    dn1Dp[k]=(zw1[k]-zST[2,ifind])/10.0
                try:
                    ifind1=ifind+1
                    dzint=zST[2,ifind1]-zST[2,ifind]
                except:
                    ifind1=ifind
                    dzint=1.0
                w1=(zw11-10.*dn1Dp[k]-zST[2,ifind])/dzint
                zKu[i,k]=zST[0,ifind]*w1+zST[0,ifind1]*(1-w1)+10*dn1Dp[k]
                iwc_SSRG[i,k]=(iwcST[2,ifind]*w1+iwcST[2,ifind1]*(1-w1))*10**dn1Dp[k]
                dm_SSRG[i,k]=(dmST[2,ifind]*w1+dmST[2,ifind1]*(1-w1))
                for ifreq in range(12):
                    ifreq1=ifreqC[ifreq]
                    kextI[k,ifreq]=kextST[ifreq1,ifind]*10**(dn1Dp[k])
                    salbI[k,ifreq]=kscaST[ifreq1,ifind]*10**(dn1Dp[k])
                    asymI[k,ifreq]=gST[ifreq1,ifind]
            else:
                continue
                # when zw1[k]-10*(dn1Dp[k])<zST[2,0] the scattering properties can be
                # extrapolated using power low fits
                # however, this does not happen anymore since the lookup table is extended to very small Dm
        nz=50
        dr=0.240
        temp1=temp[ic,14:64]
        pres1=press[ic,14:64]
        presf1=pressf[ic,14:65]
        qv1=qv[ic,14:64]
        iwc1=iwc_SSRG[i,:]
        rho1=pres1/(287.05*temp1)
        dm_ice=dm_SSRG[i,:]
        dnL.append(dn1Dp.copy())
        pmol,pnorm=get_pnorm(nz,dr,temp1,pres1,presf1,qv1,iwc1,rho1,dm_ice)
        ifreqC=[0,1,2,3,3,3,3,3,3,4,4,4]
        kext1D[14:64,:]+=kextI[:,:]
        salb1D[14:64,:]=salbI[:,:]
        asym1D[14:64,:]=asymI[:,:]
        salb1D/=kext1D
        emis=0.8+np.random.random()*0.2
        ebar=emis
        tb1=[]
        #freqs 0 and 1 are Ku and Ka and hence skipped
        for ik in range(2,12):
            tbout = lidSim.radtran(umu,temp[ic][0],temp[ic],height,kext1D[:,ik],salb1D[:,ik],asym1D[:,ik],fisot,emis,ebar)
            tb1.append(tbout)
            if tbout!=tbout:
                stop
        tbL.append(tb1)
        zKuL.append(zKu[i,:])
        epsL.append(emis)
        dm_SSRGL.append(dm_ice)
        pnormL.append(pnorm[0,:])
        pmolL.append(pmol[0,:])
    return zKuL,tbL,epsL,dm_SSRGL,pnormL,pmolL,dnL,iwc_SSRG

# %%
import xarray as xr
print(len(fCS_2B))

for i in range(1,len(fCS_2B)):
    print(fCS_2B[i],f2ICE[i])
    iwc,dbz_sim,temp2C,re,height,lonC,latC,iwp=read2C_ICE(f2ICE[i])
    fh=Dataset(fCS_2B[i])
    dbz=fh['Radar_Reflectivity'][:]/100.
    cpr_cmask=fh['CPR_Cloud_mask'][:]
    iwp1L,iwp2L,zwL,iwcL,reL,iL,dbzL,ikL,hL_2C=process(dbz,cpr_cmask,temp2C,iwc,re,height,iwp)
    zKuL,tbL,epsL,dm_SSRGL,pnormL,pmolL,dnL,iwc_SSRG=simObs(dbzL[:],iwcL[:],ikL[:],qv,temp,press,pressf)

    nt=len(zKuL)
    tbL=np.array(tbL)
# save the data in netcdf format
    ds=xr.Dataset({'tb':(['time','chan'],tbL[0:nt,:]),
                'zKu':(['time','height'],zKuL),
                'pnorm':(['time','height'],1e3*np.array(pnormL)),
                'iwc_SSRG':(['time','height'],iwc_SSRG[0:nt,:]),
                'eps':(['time'],epsL),
                'dm_SSRG':(['time','height'],dm_SSRGL[0:nt]),
                'pmol':(['time','height'],1e3*np.array(pmolL))},
                coords={'time':np.arange(len(tbL[0:nt,:])),
                        'chan':np.arange(10),
                        'height':np.arange(50)})
    granule=(f2ICE[i].split('_')[1])
    ds.to_netcdf('simObs/simObsAlongTrack_%s.nc'%granule,format='NETCDF4',encoding={'tb':{'zlib':True,'complevel':5},\
        'zKu':{'zlib':True,'complevel':5},'iwc_SSRG':{'zlib':True,'complevel':5},\
        'pnorm':{'zlib':True,'complevel':5},'dm_SSRG': {'zlib': True, 'complevel': 5},\
        'eps':{'zlib':True,'complevel':5},'pmol':{'zlib':True,'complevel':5}})
# Out:
# 132
# CloudSat_2B/2019152011900_69733_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019152011900_69733_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 7527
# CloudSat_2B/2019152025731_69734_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019152025731_69734_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 7584
# CloudSat_2B/2019152043603_69735_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019152043603_69735_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5638
# CloudSat_2B/2019152061435_69736_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019152061435_69736_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5930
# CloudSat_2B/2019152075307_69737_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019152075307_69737_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6560
# CloudSat_2B/2019152093140_69738_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019152093140_69738_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6093
# CloudSat_2B/2019152111011_69739_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019152111011_69739_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6334
# CloudSat_2B/2019152124843_69740_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019152124843_69740_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5641
# CloudSat_2B/2019152142715_69741_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019152142715_69741_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4077
# CloudSat_2B/2019152160547_69742_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019152160547_69742_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4312
# CloudSat_2B/2019152174419_69743_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019152174419_69743_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5231
# CloudSat_2B/2019152192251_69744_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019152192251_69744_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6772
# CloudSat_2B/2019152210123_69745_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019152210123_69745_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4253
# CloudSat_2B/2019152223955_69746_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019152223955_69746_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6554
# CloudSat_2B/2019153001827_69747_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019153001827_69747_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6680
# CloudSat_2B/2019153015659_69748_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019153015659_69748_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6223
# CloudSat_2B/2019153033531_69749_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019153033531_69749_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5384
# CloudSat_2B/2019153051403_69750_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019153051403_69750_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6529
# CloudSat_2B/2019153065235_69751_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019153065235_69751_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6682
# CloudSat_2B/2019153083107_69752_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019153083107_69752_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5282
# CloudSat_2B/2019153100939_69753_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019153100939_69753_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5121
# CloudSat_2B/2019153114811_69754_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019153114811_69754_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5266
# CloudSat_2B/2019153132643_69755_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019153132643_69755_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5738
# CloudSat_2B/2019153150515_69756_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019153150515_69756_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 2845
# CloudSat_2B/2019153164346_69757_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019153164346_69757_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5820
# CloudSat_2B/2019153182218_69758_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019153182218_69758_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 3388
# CloudSat_2B/2019153200050_69759_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019153200050_69759_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5372
# CloudSat_2B/2019153213922_69760_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019153213922_69760_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5259
# CloudSat_2B/2019153231754_69761_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019153231754_69761_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6089
# CloudSat_2B/2019154005626_69762_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019154005626_69762_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 9054
# CloudSat_2B/2019154023458_69763_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019154023458_69763_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5668
# CloudSat_2B/2019154041330_69764_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019154041330_69764_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6301
# CloudSat_2B/2019154055202_69765_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019154055202_69765_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6637
# CloudSat_2B/2019154073034_69766_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019154073034_69766_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 7848
# CloudSat_2B/2019154090906_69767_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019154090906_69767_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4133
# CloudSat_2B/2019154104738_69768_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019154104738_69768_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6663
# CloudSat_2B/2019154122610_69769_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019154122610_69769_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4547
# CloudSat_2B/2019154140442_69770_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019154140442_69770_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 2795
# CloudSat_2B/2019154154314_69771_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019154154314_69771_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4421
# CloudSat_2B/2019154172146_69772_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019154172146_69772_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4237
# CloudSat_2B/2019154190018_69773_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019154190018_69773_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 7267
# CloudSat_2B/2019154203850_69774_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019154203850_69774_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4947
# CloudSat_2B/2019154221722_69775_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019154221722_69775_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6306
# CloudSat_2B/2019154235554_69776_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019154235554_69776_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5544
# CloudSat_2B/2019155013426_69777_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019155013426_69777_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6753
# CloudSat_2B/2019155031258_69778_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019155031258_69778_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 7251
# CloudSat_2B/2019155045129_69779_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019155045129_69779_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6301
# CloudSat_2B/2019155063001_69780_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019155063001_69780_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 7285
# CloudSat_2B/2019155080834_69781_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019155080834_69781_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5201
# CloudSat_2B/2019155094706_69782_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019155094706_69782_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4400
# CloudSat_2B/2019155112538_69783_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019155112538_69783_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5088
# CloudSat_2B/2019155130409_69784_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019155130409_69784_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 3645
# CloudSat_2B/2019155144241_69785_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019155144241_69785_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 3710
# CloudSat_2B/2019155162113_69786_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019155162113_69786_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4324
# CloudSat_2B/2019155175945_69787_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019155175945_69787_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 7486
# CloudSat_2B/2019155193817_69788_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019155193817_69788_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6718
# CloudSat_2B/2019155211649_69789_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019155211649_69789_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4291
# CloudSat_2B/2019155225521_69790_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019155225521_69790_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4504
# CloudSat_2B/2019156003353_69791_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019156003353_69791_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4936
# CloudSat_2B/2019156021225_69792_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019156021225_69792_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6587
# CloudSat_2B/2019156035057_69793_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019156035057_69793_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6979
# CloudSat_2B/2019156052929_69794_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019156052929_69794_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 7012
# CloudSat_2B/2019156070801_69795_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019156070801_69795_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5931
# CloudSat_2B/2019156084633_69796_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019156084633_69796_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 3625
# CloudSat_2B/2019156102505_69797_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019156102505_69797_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4956
# CloudSat_2B/2019156120337_69798_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019156120337_69798_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6478
# CloudSat_2B/2019156134209_69799_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019156134209_69799_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 3168
# CloudSat_2B/2019156152041_69800_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019156152041_69800_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 3776
# CloudSat_2B/2019156165913_69801_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019156165913_69801_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 7523
# CloudSat_2B/2019156183744_69802_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019156183744_69802_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6194
# CloudSat_2B/2019156201616_69803_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019156201616_69803_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4904
# CloudSat_2B/2019156215449_69804_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019156215449_69804_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5680
# CloudSat_2B/2019156233320_69805_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019156233320_69805_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 7392
# CloudSat_2B/2019157011152_69806_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019157011152_69806_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6079
# CloudSat_2B/2019157025024_69807_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019157025024_69807_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 7534
# CloudSat_2B/2019157042856_69808_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019157042856_69808_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 7761
# CloudSat_2B/2019157060728_69809_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019157060728_69809_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6397
# CloudSat_2B/2019157074600_69810_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019157074600_69810_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4901
# CloudSat_2B/2019157092432_69811_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019157092432_69811_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 3183
# CloudSat_2B/2019157110304_69812_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019157110304_69812_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4720
# CloudSat_2B/2019157124136_69813_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019157124136_69813_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4706
# CloudSat_2B/2019157142008_69814_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019157142008_69814_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 3235
# CloudSat_2B/2019157155840_69815_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019157155840_69815_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4880
# CloudSat_2B/2019157173712_69816_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019157173712_69816_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6522
# CloudSat_2B/2019157191544_69817_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019157191544_69817_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4861
# CloudSat_2B/2019157205416_69818_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019157205416_69818_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6002
# CloudSat_2B/2019157223248_69819_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019157223248_69819_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5343
# CloudSat_2B/2019158001120_69820_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019158001120_69820_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4069
# CloudSat_2B/2019158014952_69821_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019158014952_69821_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5714
# CloudSat_2B/2019158032824_69822_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019158032824_69822_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 8078
# CloudSat_2B/2019158050655_69823_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019158050655_69823_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6725
# CloudSat_2B/2019158064527_69824_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019158064527_69824_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6397
# CloudSat_2B/2019158082359_69825_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019158082359_69825_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4248
# CloudSat_2B/2019158100232_69826_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019158100232_69826_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4198
# CloudSat_2B/2019158114103_69827_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019158114103_69827_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4827
# CloudSat_2B/2019158131935_69828_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019158131935_69828_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 2877
# CloudSat_2B/2019158145807_69829_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019158145807_69829_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 2708
# CloudSat_2B/2019158163639_69830_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019158163639_69830_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 7995
# CloudSat_2B/2019158181511_69831_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019158181511_69831_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 7044
# CloudSat_2B/2019158195343_69832_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019158195343_69832_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5136
# CloudSat_2B/2019158213215_69833_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019158213215_69833_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6804
# CloudSat_2B/2019158231047_69834_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019158231047_69834_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6975
# CloudSat_2B/2019159004919_69835_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019159004919_69835_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6708
# CloudSat_2B/2019159022751_69836_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019159022751_69836_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4891
# CloudSat_2B/2019159040623_69837_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019159040623_69837_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 8399
# CloudSat_2B/2019159054455_69838_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019159054455_69838_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 7554
# CloudSat_2B/2019159072327_69839_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019159072327_69839_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5970
# CloudSat_2B/2019159090159_69840_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019159090159_69840_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5392
# CloudSat_2B/2019159104031_69841_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019159104031_69841_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 3222
# CloudSat_2B/2019159121903_69842_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019159121903_69842_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4894
# CloudSat_2B/2019159135735_69843_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019159135735_69843_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 2306
# CloudSat_2B/2019159153606_69844_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019159153606_69844_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5241
# CloudSat_2B/2019159171438_69845_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019159171438_69845_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 7123
# CloudSat_2B/2019159185310_69846_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019159185310_69846_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 5500
# CloudSat_2B/2019159203142_69847_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019159203142_69847_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4947
# CloudSat_2B/2019159221014_69848_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019159221014_69848_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 6859
# CloudSat_2B/2019159234846_69849_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019159234846_69849_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# 4909
# CloudSat_2B/2019160012718_69850_CS_2B-GEOPROF_GRANULE_P1_R05_E08_F03.hdf data/2019160012718_69850_CS_2C-ICE_GRANULE_P1_R05_E08_F03.hdf
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/mgrecu/codePapers/synergIceRetrievals/forwardModels/obsSimulator_mgranules.ipynb Cell 8 line 7
#       <a href='vscode-notebook-cell:/Users/mgrecu/codePapers/synergIceRetrievals/forwardModels/obsSimulator_mgranules.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a> print(fCS_2B[i],f2ICE[i])
#       <a href='vscode-notebook-cell:/Users/mgrecu/codePapers/synergIceRetrievals/forwardModels/obsSimulator_mgranules.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a> iwc,dbz_sim,temp2C,re,height,lonC,latC,iwp=read2C_ICE(f2ICE[i])
# ----> <a href='vscode-notebook-cell:/Users/mgrecu/codePapers/synergIceRetrievals/forwardModels/obsSimulator_mgranules.ipynb#X16sZmlsZQ%3D%3D?line=6'>7</a> fh=Dataset(fCS_2B[i+14])
#       <a href='vscode-notebook-cell:/Users/mgrecu/codePapers/synergIceRetrievals/forwardModels/obsSimulator_mgranules.ipynb#X16sZmlsZQ%3D%3D?line=7'>8</a> dbz=fh['Radar_Reflectivity'][:]/100.
#       <a href='vscode-notebook-cell:/Users/mgrecu/codePapers/synergIceRetrievals/forwardModels/obsSimulator_mgranules.ipynb#X16sZmlsZQ%3D%3D?line=8'>9</a> cpr_cmask=fh['CPR_Cloud_mask'][:]
#
# IndexError: list index out of range

# %%
print(i)
# Out:
# 21

# %%
iwc_SSRGm=np.ma.array(iwc_SSRG,mask=iwc_SSRG<1e-3)
plt.pcolormesh(iwc_SSRGm[:,:].T,cmap='jet',norm=matplotlib.colors.LogNorm(vmin=1e-2,vmax=5e-1))
